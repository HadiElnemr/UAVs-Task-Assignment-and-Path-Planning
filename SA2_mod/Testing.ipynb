# %%
from Task_Assignment import *
from Test_cases import sys1,sys2,sys3,sys4
# from classes import *

# %%
test_sys_SA=copy.deepcopy(sys4)
test_sys_SA.plott()
simulated_annealing_TaskAssignment(test_sys_SA,1000,0.1,0.1)
test_sys_SA.plott()

# %%
test_sys_SA=copy.deepcopy(sys4)
test_sys_SA.plott()
test_sys_SA.update_UAVs(GA_TaskAssignment(test_sys_SA,0.1,0.8,0.1,20,500))
test_sys_SA.plott()
# Out:
# The initial best fitness =  56201.28727741674
# The best fitness =  47840.144659153455
# ...
